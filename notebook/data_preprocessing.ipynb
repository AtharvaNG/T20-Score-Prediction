# %%
import pandas as pd

# %%
df=pd.read_pickle("data/raw_df.pkl")
df.shape
# Out:
# (4801, 14)

# %%
df.columns.tolist()
# Out:
# ['match_id',
#  'dates',
#  'gender',
#  'match_type',
#  'winner',
#  'overs',
#  'player_of_the_match',
#  'teams',
#  'toss_decision',
#  'toss_winner',
#  'umpires',
#  'venue',
#  'city',
#  'innings']
